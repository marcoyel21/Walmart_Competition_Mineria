# %%
import pickle

# %%
selected_feat = ['DepartmentDescription_BEAUTY',
       'DepartmentDescription_CANDY, TOBACCO, COOKIES',
       'DepartmentDescription_COMM BREAD', 'DepartmentDescription_DAIRY',
       'DepartmentDescription_DSD GROCERY',
       'DepartmentDescription_FINANCIAL SERVICES',
       'DepartmentDescription_FROZEN FOODS',
       'DepartmentDescription_GROCERY DRY GOODS',
       'DepartmentDescription_HOUSEHOLD CHEMICALS/SUPP',
       'DepartmentDescription_HOUSEHOLD PAPER GOODS',
       'DepartmentDescription_IMPULSE MERCHANDISE',
       'DepartmentDescription_INFANT CONSUMABLE HARDLINES',
       'DepartmentDescription_MENS WEAR',
       'DepartmentDescription_PERSONAL CARE',
       'DepartmentDescription_PETS AND SUPPLIES',
       'DepartmentDescription_PHARMACY OTC',
       'DepartmentDescription_PHARMACY RX', 'DepartmentDescription_PRODUCE',
       'DepartmentDescription_SERVICE DELI', 'regreso', 'variedad']

# %%
pickle.dump( selected_feat, open( "pickles/selected_feat", "wb" ) )

# %%
selected_feat_ok = open("pickles/selected_feat","rb")

# %%
selected_feat_ok = pickle.load(selected_feat_ok)

# %%
selected_feat_ok
# Out:
# ['DepartmentDescription_BEAUTY',
#  'DepartmentDescription_CANDY, TOBACCO, COOKIES',
#  'DepartmentDescription_COMM BREAD',
#  'DepartmentDescription_DAIRY',
#  'DepartmentDescription_DSD GROCERY',
#  'DepartmentDescription_FINANCIAL SERVICES',
#  'DepartmentDescription_FROZEN FOODS',
#  'DepartmentDescription_GROCERY DRY GOODS',
#  'DepartmentDescription_HOUSEHOLD CHEMICALS/SUPP',
#  'DepartmentDescription_HOUSEHOLD PAPER GOODS',
#  'DepartmentDescription_IMPULSE MERCHANDISE',
#  'DepartmentDescription_INFANT CONSUMABLE HARDLINES',
#  'DepartmentDescription_MENS WEAR',
#  'DepartmentDescription_PERSONAL CARE',
#  'DepartmentDescription_PETS AND SUPPLIES',
#  'DepartmentDescription_PHARMACY OTC',
#  'DepartmentDescription_PHARMACY RX',
#  'DepartmentDescription_PRODUCE',
#  'DepartmentDescription_SERVICE DELI',
#  'regreso',
#  'variedad']

# %%
model_rf = open("pickles/selected_feat","rb")

# %%
model_rf = pickle.load(open("pickles/random_forest_21_columns","rb"))

# %%
model_rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=1136863942),
#  DecisionTreeClassifier(max_features='auto', random_state=937275820),
#  DecisionTreeClassifier(max_features='auto', random_state=1546732657),
#  DecisionTreeClassifier(max_features='auto', random_state=2074471451),
#  DecisionTreeClassifier(max_features='auto', random_state=1667325757),
#  DecisionTreeClassifier(max_features='auto', random_state=820519677),
#  DecisionTreeClassifier(max_features='auto', random_state=1291523523),
#  DecisionTreeClassifier(max_features='auto', random_state=711314233),
#  DecisionTreeClassifier(max_features='auto', random_state=1859675834),
#  DecisionTreeClassifier(max_features='auto', random_state=361737096),
#  DecisionTreeClassifier(max_features='auto', random_state=893354899),
#  DecisionTreeClassifier(max_features='auto', random_state=1623642045),
#  DecisionTreeClassifier(max_features='auto', random_state=2083075247),
#  DecisionTreeClassifier(max_features='auto', random_state=921192073),
#  DecisionTreeClassifier(max_features='auto', random_state=1285771490),
#  DecisionTreeClassifier(max_features='auto', random_state=1274759917),
#  DecisionTreeClassifier(max_features='auto', random_state=1910280577),
#  DecisionTreeClassifier(max_features='auto', random_state=1876107591),
#  DecisionTreeClassifier(max_features='auto', random_state=1187735171),
#  DecisionTreeClassifier(max_features='auto', random_state=532861465),
#  DecisionTreeClassifier(max_features='auto', random_state=1092326795),
#  DecisionTreeClassifier(max_features='auto', random_state=1747382957),
#  DecisionTreeClassifier(max_features='auto', random_state=976258184),
#  DecisionTreeClassifier(max_features='auto', random_state=1530172883),
#  DecisionTreeClassifier(max_features='auto', random_state=2076876137),
#  DecisionTreeClassifier(max_features='auto', random_state=821442914),
#  DecisionTreeClassifier(max_features='auto', random_state=1707161056),
#  DecisionTreeClassifier(max_features='auto', random_state=1221349621),
#  DecisionTreeClassifier(max_features='auto', random_state=1579468968),
#  DecisionTreeClassifier(max_features='auto', random_state=2017778644),
#  DecisionTreeClassifier(max_features='auto', random_state=1054260601),
#  DecisionTreeClassifier(max_features='auto', random_state=495919065),
#  DecisionTreeClassifier(max_features='auto', random_state=1299493721),
#  DecisionTreeClassifier(max_features='auto', random_state=1719224672),
#  DecisionTreeClassifier(max_features='auto', random_state=1525528324),
#  DecisionTreeClassifier(max_features='auto', random_state=1838014581),
#  DecisionTreeClassifier(max_features='auto', random_state=2029220676),
#  DecisionTreeClassifier(max_features='auto', random_state=972270726),
#  DecisionTreeClassifier(max_features='auto', random_state=520582383),
#  DecisionTreeClassifier(max_features='auto', random_state=1840639496),
#  DecisionTreeClassifier(max_features='auto', random_state=1620267431),
#  DecisionTreeClassifier(max_features='auto', random_state=1527210561),
#  DecisionTreeClassifier(max_features='auto', random_state=1733967443),
#  DecisionTreeClassifier(max_features='auto', random_state=437673407),
#  DecisionTreeClassifier(max_features='auto', random_state=710989589),
#  DecisionTreeClassifier(max_features='auto', random_state=1510468518),
#  DecisionTreeClassifier(max_features='auto', random_state=340131885),
#  DecisionTreeClassifier(max_features='auto', random_state=830219966),
#  DecisionTreeClassifier(max_features='auto', random_state=1418383931),
#  DecisionTreeClassifier(max_features='auto', random_state=1993912670),
#  DecisionTreeClassifier(max_features='auto', random_state=1343438432),
#  DecisionTreeClassifier(max_features='auto', random_state=1852211509),
#  DecisionTreeClassifier(max_features='auto', random_state=1679696961),
#  DecisionTreeClassifier(max_features='auto', random_state=2019175948),
#  DecisionTreeClassifier(max_features='auto', random_state=1676925529),
#  DecisionTreeClassifier(max_features='auto', random_state=1896549452),
#  DecisionTreeClassifier(max_features='auto', random_state=799292172),
#  DecisionTreeClassifier(max_features='auto', random_state=1112247279),
#  DecisionTreeClassifier(max_features='auto', random_state=1811694942),
#  DecisionTreeClassifier(max_features='auto', random_state=1209858481),
#  DecisionTreeClassifier(max_features='auto', random_state=1735894233),
#  DecisionTreeClassifier(max_features='auto', random_state=825655130),
#  DecisionTreeClassifier(max_features='auto', random_state=1724374828),
#  DecisionTreeClassifier(max_features='auto', random_state=1614807211),
#  DecisionTreeClassifier(max_features='auto', random_state=586496048),
#  DecisionTreeClassifier(max_features='auto', random_state=959325045),
#  DecisionTreeClassifier(max_features='auto', random_state=890744926),
#  DecisionTreeClassifier(max_features='auto', random_state=1970397446),
#  DecisionTreeClassifier(max_features='auto', random_state=1534728616),
#  DecisionTreeClassifier(max_features='auto', random_state=1759626182),
#  DecisionTreeClassifier(max_features='auto', random_state=927015407),
#  DecisionTreeClassifier(max_features='auto', random_state=1602511362),
#  DecisionTreeClassifier(max_features='auto', random_state=2064724412),
#  DecisionTreeClassifier(max_features='auto', random_state=1240843972),
#  DecisionTreeClassifier(max_features='auto', random_state=1049476752),
#  DecisionTreeClassifier(max_features='auto', random_state=928424669),
#  DecisionTreeClassifier(max_features='auto', random_state=870494842),
#  DecisionTreeClassifier(max_features='auto', random_state=1436300083),
#  DecisionTreeClassifier(max_features='auto', random_state=530672059),
#  DecisionTreeClassifier(max_features='auto', random_state=2121697151),
#  DecisionTreeClassifier(max_features='auto', random_state=1839433174),
#  DecisionTreeClassifier(max_features='auto', random_state=413535523),
#  DecisionTreeClassifier(max_features='auto', random_state=52760838),
#  DecisionTreeClassifier(max_features='auto', random_state=1569025885),
#  DecisionTreeClassifier(max_features='auto', random_state=980685763),
#  DecisionTreeClassifier(max_features='auto', random_state=318358764),
#  DecisionTreeClassifier(max_features='auto', random_state=223775374),
#  DecisionTreeClassifier(max_features='auto', random_state=1516770631),
#  DecisionTreeClassifier(max_features='auto', random_state=1401183921),
#  DecisionTreeClassifier(max_features='auto', random_state=1554026048),
#  DecisionTreeClassifier(max_features='auto', random_state=1497455187),
#  DecisionTreeClassifier(max_features='auto', random_state=864976013),
#  DecisionTreeClassifier(max_features='auto', random_state=1906982875),
#  DecisionTreeClassifier(max_features='auto', random_state=1881116491),
#  DecisionTreeClassifier(max_features='auto', random_state=456799736),
#  DecisionTreeClassifier(max_features='auto', random_state=1411454340),
#  DecisionTreeClassifier(max_features='auto', random_state=842326984),
#  DecisionTreeClassifier(max_features='auto', random_state=1993663971),
#  DecisionTreeClassifier(max_features='auto', random_state=408685479),
#  DecisionTreeClassifier(max_features='auto', random_state=810664942),
#  DecisionTreeClassifier(max_features='auto', random_state=1937724929),
#  DecisionTreeClassifier(max_features='auto', random_state=1753330516),
#  DecisionTreeClassifier(max_features='auto', random_state=233124022),
#  DecisionTreeClassifier(max_features='auto', random_state=854972196),
#  DecisionTreeClassifier(max_features='auto', random_state=259355457),
#  DecisionTreeClassifier(max_features='auto', random_state=1492994962),
#  DecisionTreeClassifier(max_features='auto', random_state=1227788803),
#  DecisionTreeClassifier(max_features='auto', random_state=2067125966),
#  DecisionTreeClassifier(max_features='auto', random_state=1501684878),
#  DecisionTreeClassifier(max_features='auto', random_state=2058744177),
#  DecisionTreeClassifier(max_features='auto', random_state=670430730),
#  DecisionTreeClassifier(max_features='auto', random_state=1248078406),
#  DecisionTreeClassifier(max_features='auto', random_state=699057821),
#  DecisionTreeClassifier(max_features='auto', random_state=643759247),
#  DecisionTreeClassifier(max_features='auto', random_state=679580674),
#  DecisionTreeClassifier(max_features='auto', random_state=203736138),
#  DecisionTreeClassifier(max_features='auto', random_state=1600377099),
#  DecisionTreeClassifier(max_features='auto', random_state=640906478),
#  DecisionTreeClassifier(max_features='auto', random_state=1412483702),
#  DecisionTreeClassifier(max_features='auto', random_state=1141534886),
#  DecisionTreeClassifier(max_features='auto', random_state=213417869),
#  DecisionTreeClassifier(max_features='auto', random_state=68183872),
#  DecisionTreeClassifier(max_features='auto', random_state=1623298908),
#  DecisionTreeClassifier(max_features='auto', random_state=1016010710),
#  DecisionTreeClassifier(max_features='auto', random_state=1999791972),
#  DecisionTreeClassifier(max_features='auto', random_state=1190977367),
#  DecisionTreeClassifier(max_features='auto', random_state=619507524),
#  DecisionTreeClassifier(max_features='auto', random_state=1256594019),
#  DecisionTreeClassifier(max_features='auto', random_state=462406937),
#  DecisionTreeClassifier(max_features='auto', random_state=1578180795),
#  DecisionTreeClassifier(max_features='auto', random_state=171714289),
#  DecisionTreeClassifier(max_features='auto', random_state=528191293),
#  DecisionTreeClassifier(max_features='auto', random_state=1743522871),
#  DecisionTreeClassifier(max_features='auto', random_state=1228792007),
#  DecisionTreeClassifier(max_features='auto', random_state=1386348794),
#  DecisionTreeClassifier(max_features='auto', random_state=1980269209),
#  DecisionTreeClassifier(max_features='auto', random_state=1781248518),
#  DecisionTreeClassifier(max_features='auto', random_state=958009996),
#  DecisionTreeClassifier(max_features='auto', random_state=1489624477),
#  DecisionTreeClassifier(max_features='auto', random_state=526340397),
#  DecisionTreeClassifier(max_features='auto', random_state=156266287),
#  DecisionTreeClassifier(max_features='auto', random_state=1252182999),
#  DecisionTreeClassifier(max_features='auto', random_state=311912999),
#  DecisionTreeClassifier(max_features='auto', random_state=690508770),
#  DecisionTreeClassifier(max_features='auto', random_state=204658432),
#  DecisionTreeClassifier(max_features='auto', random_state=1253391714),
#  DecisionTreeClassifier(max_features='auto', random_state=651427427),
#  DecisionTreeClassifier(max_features='auto', random_state=1100392907),
#  DecisionTreeClassifier(max_features='auto', random_state=1426261768),
#  DecisionTreeClassifier(max_features='auto', random_state=1656415036),
#  DecisionTreeClassifier(max_features='auto', random_state=2129083463),
#  DecisionTreeClassifier(max_features='auto', random_state=681210540),
#  DecisionTreeClassifier(max_features='auto', random_state=1009117058),
#  DecisionTreeClassifier(max_features='auto', random_state=314744490),
#  DecisionTreeClassifier(max_features='auto', random_state=813290323),
#  DecisionTreeClassifier(max_features='auto', random_state=469288041),
#  DecisionTreeClassifier(max_features='auto', random_state=1829279591),
#  DecisionTreeClassifier(max_features='auto', random_state=153472152),
#  DecisionTreeClassifier(max_features='auto', random_state=737743480),
#  DecisionTreeClassifier(max_features='auto', random_state=577497422),
#  DecisionTreeClassifier(max_features='auto', random_state=1683086077),
#  DecisionTreeClassifier(max_features='auto', random_state=315401339),
#  DecisionTreeClassifier(max_features='auto', random_state=1884220206),
#  DecisionTreeClassifier(max_features='auto', random_state=681440042),
#  DecisionTreeClassifier(max_features='auto', random_state=1301090510),
#  DecisionTreeClassifier(max_features='auto', random_state=1945768755),
#  DecisionTreeClassifier(max_features='auto', random_state=130931232),
#  DecisionTreeClassifier(max_features='auto', random_state=401070925),
#  DecisionTreeClassifier(max_features='auto', random_state=864464522),
#  DecisionTreeClassifier(max_features='auto', random_state=2036127362),
#  DecisionTreeClassifier(max_features='auto', random_state=30636691),
#  DecisionTreeClassifier(max_features='auto', random_state=103825390),
#  DecisionTreeClassifier(max_features='auto', random_state=1977584856),
#  DecisionTreeClassifier(max_features='auto', random_state=1106728682),
#  DecisionTreeClassifier(max_features='auto', random_state=2130900524),
#  DecisionTreeClassifier(max_features='auto', random_state=1526727437),
#  DecisionTreeClassifier(max_features='auto', random_state=623936921),
#  DecisionTreeClassifier(max_features='auto', random_state=1554126257),
#  DecisionTreeClassifier(max_features='auto', random_state=545515789),
#  DecisionTreeClassifier(max_features='auto', random_state=1735185255),
#  DecisionTreeClassifier(max_features='auto', random_state=5836787),
#  DecisionTreeClassifier(max_features='auto', random_state=1601338542),
#  DecisionTreeClassifier(max_features='auto', random_state=1331049083),
#  DecisionTreeClassifier(max_features='auto', random_state=1384389101),
#  DecisionTreeClassifier(max_features='auto', random_state=422268800),
#  DecisionTreeClassifier(max_features='auto', random_state=874788873),
#  DecisionTreeClassifier(max_features='auto', random_state=1532467257),
#  DecisionTreeClassifier(max_features='auto', random_state=924831323),
#  DecisionTreeClassifier(max_features='auto', random_state=1843724338),
#  DecisionTreeClassifier(max_features='auto', random_state=1468362791),
#  DecisionTreeClassifier(max_features='auto', random_state=1258374060),
#  DecisionTreeClassifier(max_features='auto', random_state=1618001089),
#  DecisionTreeClassifier(max_features='auto', random_state=1605361115),
#  DecisionTreeClassifier(max_features='auto', random_state=994440599),
#  DecisionTreeClassifier(max_features='auto', random_state=1432076069),
#  DecisionTreeClassifier(max_features='auto', random_state=531624994),
#  DecisionTreeClassifier(max_features='auto', random_state=670071584),
#  DecisionTreeClassifier(max_features='auto', random_state=18129169),
#  DecisionTreeClassifier(max_features='auto', random_state=297918618),
#  DecisionTreeClassifier(max_features='auto', random_state=2019104052),
#  DecisionTreeClassifier(max_features='auto', random_state=1766327320),
#  DecisionTreeClassifier(max_features='auto', random_state=1283178793),
#  DecisionTreeClassifier(max_features='auto', random_state=1001188396),
#  DecisionTreeClassifier(max_features='auto', random_state=1041961420),
#  DecisionTreeClassifier(max_features='auto', random_state=536516895),
#  DecisionTreeClassifier(max_features='auto', random_state=156110409),
#  DecisionTreeClassifier(max_features='auto', random_state=2144737872),
#  DecisionTreeClassifier(max_features='auto', random_state=1278175914),
#  DecisionTreeClassifier(max_features='auto', random_state=1242742933),
#  DecisionTreeClassifier(max_features='auto', random_state=817631286),
#  DecisionTreeClassifier(max_features='auto', random_state=682849253),
#  DecisionTreeClassifier(max_features='auto', random_state=916963399),
#  DecisionTreeClassifier(max_features='auto', random_state=1043753366),
#  DecisionTreeClassifier(max_features='auto', random_state=1680024687),
#  DecisionTreeClassifier(max_features='auto', random_state=1996466392),
#  DecisionTreeClassifier(max_features='auto', random_state=455445737),
#  DecisionTreeClassifier(max_features='auto', random_state=933441253),
#  DecisionTreeClassifier(max_features='auto', random_state=1275030289),
#  DecisionTreeClassifier(max_features='auto', random_state=1735533323),
#  DecisionTreeClassifier(max_features='auto', random_state=495578965),
#  DecisionTreeClassifier(max_features='auto', random_state=1280140419),
#  DecisionTreeClassifier(max_features='auto', random_state=1638547554),
#  DecisionTreeClassifier(max_features='auto', random_state=272310424),
#  DecisionTreeClassifier(max_features='auto', random_state=1509086725),
#  DecisionTreeClassifier(max_features='auto', random_state=1717659665),
#  DecisionTreeClassifier(max_features='auto', random_state=472740188),
#  DecisionTreeClassifier(max_features='auto', random_state=531325105),
#  DecisionTreeClassifier(max_features='auto', random_state=1930074587),
#  DecisionTreeClassifier(max_features='auto', random_state=1025406088),
#  DecisionTreeClassifier(max_features='auto', random_state=360953691),
#  DecisionTreeClassifier(max_features='auto', random_state=1451665623),
#  DecisionTreeClassifier(max_features='auto', random_state=547519388),
#  DecisionTreeClassifier(max_features='auto', random_state=620779044),
#  DecisionTreeClassifier(max_features='auto', random_state=1345573187),
#  DecisionTreeClassifier(max_features='auto', random_state=393788317),
#  DecisionTreeClassifier(max_features='auto', random_state=1620494781),
#  DecisionTreeClassifier(max_features='auto', random_state=1192409766),
#  DecisionTreeClassifier(max_features='auto', random_state=85842703),
#  DecisionTreeClassifier(max_features='auto', random_state=1284155257),
#  DecisionTreeClassifier(max_features='auto', random_state=1651953346),
#  DecisionTreeClassifier(max_features='auto', random_state=1172664183),
#  DecisionTreeClassifier(max_features='auto', random_state=2088353722),
#  DecisionTreeClassifier(max_features='auto', random_state=1448930790),
#  DecisionTreeClassifier(max_features='auto', random_state=857009226),
#  DecisionTreeClassifier(max_features='auto', random_state=511127122),
#  DecisionTreeClassifier(max_features='auto', random_state=671724226),
#  DecisionTreeClassifier(max_features='auto', random_state=1928797331),
#  DecisionTreeClassifier(max_features='auto', random_state=284676417),
#  DecisionTreeClassifier(max_features='auto', random_state=1481203605),
#  DecisionTreeClassifier(max_features='auto', random_state=1996958909),
#  DecisionTreeClassifier(max_features='auto', random_state=857477818),
#  DecisionTreeClassifier(max_features='auto', random_state=1560113442),
#  DecisionTreeClassifier(max_features='auto', random_state=121635257),
#  DecisionTreeClassifier(max_features='auto', random_state=1481338252),
#  DecisionTreeClassifier(max_features='auto', random_state=1900671235),
#  DecisionTreeClassifier(max_features='auto', random_state=347144770),
#  DecisionTreeClassifier(max_features='auto', random_state=2118537179),
#  DecisionTreeClassifier(max_features='auto', random_state=877092498),
#  DecisionTreeClassifier(max_features='auto', random_state=649122967),
#  DecisionTreeClassifier(max_features='auto', random_state=761773474),
#  DecisionTreeClassifier(max_features='auto', random_state=277491976),
#  DecisionTreeClassifier(max_features='auto', random_state=1134276030),
#  DecisionTreeClassifier(max_features='auto', random_state=1534607608),
#  DecisionTreeClassifier(max_features='auto', random_state=1451865925),
#  DecisionTreeClassifier(max_features='auto', random_state=866597947),
#  DecisionTreeClassifier(max_features='auto', random_state=1919685467),
#  DecisionTreeClassifier(max_features='auto', random_state=71263394),
#  DecisionTreeClassifier(max_features='auto', random_state=1971244237),
#  DecisionTreeClassifier(max_features='auto', random_state=1727445653),
#  DecisionTreeClassifier(max_features='auto', random_state=1098529922),
#  DecisionTreeClassifier(max_features='auto', random_state=174404086),
#  DecisionTreeClassifier(max_features='auto', random_state=1519330733),
#  DecisionTreeClassifier(max_features='auto', random_state=1091151622),
#  DecisionTreeClassifier(max_features='auto', random_state=1018361361),
#  DecisionTreeClassifier(max_features='auto', random_state=1510307430),
#  DecisionTreeClassifier(max_features='auto', random_state=54681543),
#  DecisionTreeClassifier(max_features='auto', random_state=1549241662),
#  DecisionTreeClassifier(max_features='auto', random_state=715360244),
#  DecisionTreeClassifier(max_features='auto', random_state=732052638),
#  DecisionTreeClassifier(max_features='auto', random_state=266085053),
#  DecisionTreeClassifier(max_features='auto', random_state=970644498),
#  DecisionTreeClassifier(max_features='auto', random_state=1838797171),
#  DecisionTreeClassifier(max_features='auto', random_state=100370168),
#  DecisionTreeClassifier(max_features='auto', random_state=1319503277),
#  DecisionTreeClassifier(max_features='auto', random_state=1573302368),
#  DecisionTreeClassifier(max_features='auto', random_state=1255754412),
#  DecisionTreeClassifier(max_features='auto', random_state=1296831132),
#  DecisionTreeClassifier(max_features='auto', random_state=1990391708),
#  DecisionTreeClassifier(max_features='auto', random_state=1138114659),
#  DecisionTreeClassifier(max_features='auto', random_state=694524397),
#  DecisionTreeClassifier(max_features='auto', random_state=873223434),
#  DecisionTreeClassifier(max_features='auto', random_state=1179766485),
#  DecisionTreeClassifier(max_features='auto', random_state=1910788068),
#  DecisionTreeClassifier(max_features='auto', random_state=1889985287),
#  DecisionTreeClassifier(max_features='auto', random_state=574943232),
#  DecisionTreeClassifier(max_features='auto', random_state=1496451859),
#  DecisionTreeClassifier(max_features='auto', random_state=1978257312),
#  DecisionTreeClassifier(max_features='auto', random_state=602353739),
#  DecisionTreeClassifier(max_features='auto', random_state=1289279158),
#  DecisionTreeClassifier(max_features='auto', random_state=1264633406),
#  DecisionTreeClassifier(max_features='auto', random_state=334204137),
#  DecisionTreeClassifier(max_features='auto', random_state=1517562651),
#  DecisionTreeClassifier(max_features='auto', random_state=1778321332),
#  DecisionTreeClassifier(max_features='auto', random_state=2140185173),
#  DecisionTreeClassifier(max_features='auto', random_state=984775190),
#  DecisionTreeClassifier(max_features='auto', random_state=1247898),
#  DecisionTreeClassifier(max_features='auto', random_state=459605340),
#  DecisionTreeClassifier(max_features='auto', random_state=1140555569),
#  DecisionTreeClassifier(max_features='auto', random_state=992553227),
#  DecisionTreeClassifier(max_features='auto', random_state=2003495688),
#  DecisionTreeClassifier(max_features='auto', random_state=819668882),
#  DecisionTreeClassifier(max_features='auto', random_state=1076451784),
#  DecisionTreeClassifier(max_features='auto', random_state=90264293),
#  DecisionTreeClassifier(max_features='auto', random_state=249277654),
#  DecisionTreeClassifier(max_features='auto', random_state=871193235),
#  DecisionTreeClassifier(max_features='auto', random_state=1949108911),
#  DecisionTreeClassifier(max_features='auto', random_state=874658549),
#  DecisionTreeClassifier(max_features='auto', random_state=1965731621),
#  DecisionTreeClassifier(max_features='auto', random_state=1444590249),
#  DecisionTreeClassifier(max_features='auto', random_state=1255699092),
#  DecisionTreeClassifier(max_features='auto', random_state=180517637),
#  DecisionTreeClassifier(max_features='auto', random_state=755327608),
#  DecisionTreeClassifier(max_features='auto', random_state=92862720),
#  DecisionTreeClassifier(max_features='auto', random_state=1404448800),
#  DecisionTreeClassifier(max_features='auto', random_state=160602483),
#  DecisionTreeClassifier(max_features='auto', random_state=1059450619),
#  DecisionTreeClassifier(max_features='auto', random_state=575602974),
#  DecisionTreeClassifier(max_features='auto', random_state=1549228049),
#  DecisionTreeClassifier(max_features='auto', random_state=387932116),
#  DecisionTreeClassifier(max_features='auto', random_state=717654750),
#  DecisionTreeClassifier(max_features='auto', random_state=289124111),
#  DecisionTreeClassifier(max_features='auto', random_state=458173121),
#  DecisionTreeClassifier(max_features='auto', random_state=672897651),
#  DecisionTreeClassifier(max_features='auto', random_state=1628536405),
#  DecisionTreeClassifier(max_features='auto', random_state=2130538132),
#  DecisionTreeClassifier(max_features='auto', random_state=1467396431),
#  DecisionTreeClassifier(max_features='auto', random_state=1377885956),
#  DecisionTreeClassifier(max_features='auto', random_state=909780801),
#  DecisionTreeClassifier(max_features='auto', random_state=1331663921),
#  DecisionTreeClassifier(max_features='auto', random_state=1070599324),
#  DecisionTreeClassifier(max_features='auto', random_state=530526985),
#  DecisionTreeClassifier(max_features='auto', random_state=2018211526),
#  DecisionTreeClassifier(max_features='auto', random_state=1852103836),
#  DecisionTreeClassifier(max_features='auto', random_state=1797229167),
#  DecisionTreeClassifier(max_features='auto', random_state=1887097511),
#  DecisionTreeClassifier(max_features='auto', random_state=1832477982),
#  DecisionTreeClassifier(max_features='auto', random_state=27554738),
#  DecisionTreeClassifier(max_features='auto', random_state=691122623),
#  DecisionTreeClassifier(max_features='auto', random_state=1043273115),
#  DecisionTreeClassifier(max_features='auto', random_state=67575342),
#  DecisionTreeClassifier(max_features='auto', random_state=778439813),
#  DecisionTreeClassifier(max_features='auto', random_state=1181496948),
#  DecisionTreeClassifier(max_features='auto', random_state=1835854260),
#  DecisionTreeClassifier(max_features='auto', random_state=689553402),
#  DecisionTreeClassifier(max_features='auto', random_state=1734743360),
#  DecisionTreeClassifier(max_features='auto', random_state=1479958128),
#  DecisionTreeClassifier(max_features='auto', random_state=344366130),
#  DecisionTreeClassifier(max_features='auto', random_state=2055081801),
#  DecisionTreeClassifier(max_features='auto', random_state=41799869),
#  DecisionTreeClassifier(max_features='auto', random_state=761246458),
#  DecisionTreeClassifier(max_features='auto', random_state=1337219592),
#  DecisionTreeClassifier(max_features='auto', random_state=1330983293),
#  DecisionTreeClassifier(max_features='auto', random_state=74820281),
#  DecisionTreeClassifier(max_features='auto', random_state=136693610),
#  DecisionTreeClassifier(max_features='auto', random_state=1419441487),
#  DecisionTreeClassifier(max_features='auto', random_state=1947714906),
#  DecisionTreeClassifier(max_features='auto', random_state=858502571),
#  DecisionTreeClassifier(max_features='auto', random_state=1857067404),
#  DecisionTreeClassifier(max_features='auto', random_state=1516952575),
#  DecisionTreeClassifier(max_features='auto', random_state=1979600946),
#  DecisionTreeClassifier(max_features='auto', random_state=1206657633),
#  DecisionTreeClassifier(max_features='auto', random_state=1088576453),
#  DecisionTreeClassifier(max_features='auto', random_state=2114967979),
#  DecisionTreeClassifier(max_features='auto', random_state=119635522),
#  DecisionTreeClassifier(max_features='auto', random_state=306560942),
#  DecisionTreeClassifier(max_features='auto', random_state=1070905912),
#  DecisionTreeClassifier(max_features='auto', random_state=41916042),
#  DecisionTreeClassifier(max_features='auto', random_state=1536445696),
#  DecisionTreeClassifier(max_features='auto', random_state=528389961),
#  DecisionTreeClassifier(max_features='auto', random_state=1410030839),
#  DecisionTreeClassifier(max_features='auto', random_state=1349488863),
#  DecisionTreeClassifier(max_features='auto', random_state=1402706927),
#  DecisionTreeClassifier(max_features='auto', random_state=938957396),
#  DecisionTreeClassifier(max_features='auto', random_state=1391867623),
#  DecisionTreeClassifier(max_features='auto', random_state=1795110093),
#  DecisionTreeClassifier(max_features='auto', random_state=637303028),
#  DecisionTreeClassifier(max_features='auto', random_state=2052487620),
#  DecisionTreeClassifier(max_features='auto', random_state=548702476),
#  DecisionTreeClassifier(max_features='auto', random_state=1629921460),
#  DecisionTreeClassifier(max_features='auto', random_state=1647898535),
#  DecisionTreeClassifier(max_features='auto', random_state=919932559),
#  DecisionTreeClassifier(max_features='auto', random_state=737744666),
#  DecisionTreeClassifier(max_features='auto', random_state=20655382),
#  DecisionTreeClassifier(max_features='auto', random_state=932216871),
#  DecisionTreeClassifier(max_features='auto', random_state=1728067169),
#  DecisionTreeClassifier(max_features='auto', random_state=365538740),
#  DecisionTreeClassifier(max_features='auto', random_state=862495904),
#  DecisionTreeClassifier(max_features='auto', random_state=325666629),
#  DecisionTreeClassifier(max_features='auto', random_state=356633930),
#  DecisionTreeClassifier(max_features='auto', random_state=453554170),
#  DecisionTreeClassifier(max_features='auto', random_state=29955967),
#  DecisionTreeClassifier(max_features='auto', random_state=857392647),
#  DecisionTreeClassifier(max_features='auto', random_state=1578334671),
#  DecisionTreeClassifier(max_features='auto', random_state=1174666493),
#  DecisionTreeClassifier(max_features='auto', random_state=941736500),
#  DecisionTreeClassifier(max_features='auto', random_state=215932631),
#  DecisionTreeClassifier(max_features='auto', random_state=358257154),
#  DecisionTreeClassifier(max_features='auto', random_state=1696760377),
#  DecisionTreeClassifier(max_features='auto', random_state=1241041761),
#  DecisionTreeClassifier(max_features='auto', random_state=1327180909),
#  DecisionTreeClassifier(max_features='auto', random_state=1570786640),
#  DecisionTreeClassifier(max_features='auto', random_state=641911435),
#  DecisionTreeClassifier(max_features='auto', random_state=1730560515),
#  DecisionTreeClassifier(max_features='auto', random_state=259294541),
#  DecisionTreeClassifier(max_features='auto', random_state=973949591),
#  DecisionTreeClassifier(max_features='auto', random_state=418285081),
#  DecisionTreeClassifier(max_features='auto', random_state=1658271165),
#  DecisionTreeClassifier(max_features='auto', random_state=1809590690),
#  DecisionTreeClassifier(max_features='auto', random_state=1785853790),
#  DecisionTreeClassifier(max_features='auto', random_state=451154886),
#  DecisionTreeClassifier(max_features='auto', random_state=2011728575),
#  DecisionTreeClassifier(max_features='auto', random_state=802085162),
#  DecisionTreeClassifier(max_features='auto', random_state=1076076756),
#  DecisionTreeClassifier(max_features='auto', random_state=1481275007),
#  DecisionTreeClassifier(max_features='auto', random_state=2118600632),
#  DecisionTreeClassifier(max_features='auto', random_state=1159248836),
#  DecisionTreeClassifier(max_features='auto', random_state=302249959),
#  DecisionTreeClassifier(max_features='auto', random_state=921782432),
#  DecisionTreeClassifier(max_features='auto', random_state=1109052497),
#  DecisionTreeClassifier(max_features='auto', random_state=294830689),
#  DecisionTreeClassifier(max_features='auto', random_state=896811391),
#  DecisionTreeClassifier(max_features='auto', random_state=171296081),
#  DecisionTreeClassifier(max_features='auto', random_state=1338281174),
#  DecisionTreeClassifier(max_features='auto', random_state=1177102272),
#  DecisionTreeClassifier(max_features='auto', random_state=1424304606),
#  DecisionTreeClassifier(max_features='auto', random_state=489148718),
#  DecisionTreeClassifier(max_features='auto', random_state=1680918734),
#  DecisionTreeClassifier(max_features='auto', random_state=63997380),
#  DecisionTreeClassifier(max_features='auto', random_state=336316619),
#  DecisionTreeClassifier(max_features='auto', random_state=1701096876),
#  DecisionTreeClassifier(max_features='auto', random_state=662529072),
#  DecisionTreeClassifier(max_features='auto', random_state=716082527),
#  DecisionTreeClassifier(max_features='auto', random_state=1816774287),
#  DecisionTreeClassifier(max_features='auto', random_state=752026109),
#  DecisionTreeClassifier(max_features='auto', random_state=1475152519),
#  DecisionTreeClassifier(max_features='auto', random_state=1730222034),
#  DecisionTreeClassifier(max_features='auto', random_state=973494615),
#  DecisionTreeClassifier(max_features='auto', random_state=1112672588),
#  DecisionTreeClassifier(max_features='auto', random_state=245998608),
#  DecisionTreeClassifier(max_features='auto', random_state=57969823),
#  DecisionTreeClassifier(max_features='auto', random_state=907873066),
#  DecisionTreeClassifier(max_features='auto', random_state=2098442802),
#  DecisionTreeClassifier(max_features='auto', random_state=268066711),
#  DecisionTreeClassifier(max_features='auto', random_state=355173302),
#  DecisionTreeClassifier(max_features='auto', random_state=1678300719),
#  DecisionTreeClassifier(max_features='auto', random_state=1272309336),
#  DecisionTreeClassifier(max_features='auto', random_state=1522081280),
#  DecisionTreeClassifier(max_features='auto', random_state=533986145),
#  DecisionTreeClassifier(max_features='auto', random_state=29104964),
#  DecisionTreeClassifier(max_features='auto', random_state=645727751),
#  DecisionTreeClassifier(max_features='auto', random_state=651127008),
#  DecisionTreeClassifier(max_features='auto', random_state=1578057466),
#  DecisionTreeClassifier(max_features='auto', random_state=1114830479),
#  DecisionTreeClassifier(max_features='auto', random_state=942221771),
#  DecisionTreeClassifier(max_features='auto', random_state=370137937),
#  DecisionTreeClassifier(max_features='auto', random_state=1416820391),
#  DecisionTreeClassifier(max_features='auto', random_state=443694809),
#  DecisionTreeClassifier(max_features='auto', random_state=208449104),
#  DecisionTreeClassifier(max_features='auto', random_state=65753031),
#  DecisionTreeClassifier(max_features='auto', random_state=549198525),
#  DecisionTreeClassifier(max_features='auto', random_state=1497958822),
#  DecisionTreeClassifier(max_features='auto', random_state=1459474903),
#  DecisionTreeClassifier(max_features='auto', random_state=1672622756),
#  DecisionTreeClassifier(max_features='auto', random_state=541539701),
#  DecisionTreeClassifier(max_features='auto', random_state=155738996),
#  DecisionTreeClassifier(max_features='auto', random_state=600609719),
#  DecisionTreeClassifier(max_features='auto', random_state=960932691),
#  DecisionTreeClassifier(max_features='auto', random_state=1140911806),
#  DecisionTreeClassifier(max_features='auto', random_state=399312875),
#  DecisionTreeClassifier(max_features='auto', random_state=66624631),
#  DecisionTreeClassifier(max_features='auto', random_state=1755690972),
#  DecisionTreeClassifier(max_features='auto', random_state=1119799279),
#  DecisionTreeClassifier(max_features='auto', random_state=348892694),
#  DecisionTreeClassifier(max_features='auto', random_state=1176318328),
#  DecisionTreeClassifier(max_features='auto', random_state=895619556),
#  DecisionTreeClassifier(max_features='auto', random_state=1917247605),
#  DecisionTreeClassifier(max_features='auto', random_state=350836335),
#  DecisionTreeClassifier(max_features='auto', random_state=1269777722),
#  DecisionTreeClassifier(max_features='auto', random_state=1334572411),
#  DecisionTreeClassifier(max_features='auto', random_state=251572808),
#  DecisionTreeClassifier(max_features='auto', random_state=245159002),
#  DecisionTreeClassifier(max_features='auto', random_state=1993012274),
#  DecisionTreeClassifier(max_features='auto', random_state=628454836),
#  DecisionTreeClassifier(max_features='auto', random_state=1114554526),
#  DecisionTreeClassifier(max_features='auto', random_state=674139530),
#  DecisionTreeClassifier(max_features='auto', random_state=751337218),
#  DecisionTreeClassifier(max_features='auto', random_state=208649481),
#  DecisionTreeClassifier(max_features='auto', random_state=2025471642),
#  DecisionTreeClassifier(max_features='auto', random_state=300929982),
#  DecisionTreeClassifier(max_features='auto', random_state=538986459),
#  DecisionTreeClassifier(max_features='auto', random_state=1629281069),
#  DecisionTreeClassifier(max_features='auto', random_state=435510889),
#  DecisionTreeClassifier(max_features='auto', random_state=1018424415),
#  DecisionTreeClassifier(max_features='auto', random_state=1595037915),
#  DecisionTreeClassifier(max_features='auto', random_state=16635078),
#  DecisionTreeClassifier(max_features='auto', random_state=600935515),
#  DecisionTreeClassifier(max_features='auto', random_state=1399363548),
#  DecisionTreeClassifier(max_features='auto', random_state=709686134),
#  DecisionTreeClassifier(max_features='auto', random_state=552921596),
#  DecisionTreeClassifier(max_features='auto', random_state=987081135),
#  DecisionTreeClassifier(max_features='auto', random_state=1005962288),
#  DecisionTreeClassifier(max_features='auto', random_state=1518975742),
#  DecisionTreeClassifier(max_features='auto', random_state=382826404),
#  DecisionTreeClassifier(max_features='auto', random_state=1871792803),
#  DecisionTreeClassifier(max_features='auto', random_state=146875875),
#  DecisionTreeClassifier(max_features='auto', random_state=1752560865),
#  DecisionTreeClassifier(max_features='auto', random_state=1296685488),
#  DecisionTreeClassifier(max_features='auto', random_state=320247164),
#  DecisionTreeClassifier(max_features='auto', random_state=242660655),
#  DecisionTreeClassifier(max_features='auto', random_state=1136856769),
#  DecisionTreeClassifier(max_features='auto', random_state=1383969890),
#  DecisionTreeClassifier(max_features='auto', random_state=211355634),
#  DecisionTreeClassifier(max_features='auto', random_state=1738954636),
#  DecisionTreeClassifier(max_features='auto', random_state=905036335),
#  DecisionTreeClassifier(max_features='auto', random_state=841217282),
#  DecisionTreeClassifier(max_features='auto', random_state=1382757680),
#  DecisionTreeClassifier(max_features='auto', random_state=1557942965),
#  DecisionTreeClassifier(max_features='auto', random_state=756819652),
#  DecisionTreeClassifier(max_features='auto', random_state=675886078),
#  DecisionTreeClassifier(max_features='auto', random_state=1462505048),
#  DecisionTreeClassifier(max_features='auto', random_state=2128750470),
#  DecisionTreeClassifier(max_features='auto', random_state=1966151711),
#  DecisionTreeClassifier(max_features='auto', random_state=1548873754),
#  DecisionTreeClassifier(max_features='auto', random_state=1980189552),
#  DecisionTreeClassifier(max_features='auto', random_state=156343094),
#  DecisionTreeClassifier(max_features='auto', random_state=1145363579),
#  DecisionTreeClassifier(max_features='auto', random_state=1251128448),
#  DecisionTreeClassifier(max_features='auto', random_state=1716223189),
#  DecisionTreeClassifier(max_features='auto', random_state=1799902563),
#  DecisionTreeClassifier(max_features='auto', random_state=274220537),
#  DecisionTreeClassifier(max_features='auto', random_state=1082276488),
#  DecisionTreeClassifier(max_features='auto', random_state=40505373),
#  DecisionTreeClassifier(max_features='auto', random_state=65610200),
#  DecisionTreeClassifier(max_features='auto', random_state=2069911587),
#  DecisionTreeClassifier(max_features='auto', random_state=666685508),
#  DecisionTreeClassifier(max_features='auto', random_state=1457219631),
#  DecisionTreeClassifier(max_features='auto', random_state=1061843552),
#  DecisionTreeClassifier(max_features='auto', random_state=432188544),
#  DecisionTreeClassifier(max_features='auto', random_state=716506217),
#  DecisionTreeClassifier(max_features='auto', random_state=1954712927),
#  DecisionTreeClassifier(max_features='auto', random_state=1706260488),
#  DecisionTreeClassifier(max_features='auto', random_state=499250215),
#  DecisionTreeClassifier(max_features='auto', random_state=515793543),
#  DecisionTreeClassifier(max_features='auto', random_state=1084316347),
#  DecisionTreeClassifier(max_features='auto', random_state=102094096),
#  DecisionTreeClassifier(max_features='auto', random_state=603689667),
#  DecisionTreeClassifier(max_features='auto', random_state=1574213103),
#  DecisionTreeClassifier(max_features='auto', random_state=1228288443),
#  DecisionTreeClassifier(max_features='auto', random_state=637689647),
#  DecisionTreeClassifier(max_features='auto', random_state=695462567),
#  DecisionTreeClassifier(max_features='auto', random_state=103596159),
#  DecisionTreeClassifier(max_features='auto', random_state=1527807097),
#  DecisionTreeClassifier(max_features='auto', random_state=1404369513),
#  DecisionTreeClassifier(max_features='auto', random_state=109317194),
#  DecisionTreeClassifier(max_features='auto', random_state=867539765),
#  DecisionTreeClassifier(max_features='auto', random_state=414463818),
#  DecisionTreeClassifier(max_features='auto', random_state=1264051935),
#  DecisionTreeClassifier(max_features='auto', random_state=393057866),
#  DecisionTreeClassifier(max_features='auto', random_state=1574859135),
#  DecisionTreeClassifier(max_features='auto', random_state=474391805),
#  DecisionTreeClassifier(max_features='auto', random_state=605918245),
#  DecisionTreeClassifier(max_features='auto', random_state=250535066),
#  DecisionTreeClassifier(max_features='auto', random_state=632105597),
#  DecisionTreeClassifier(max_features='auto', random_state=226956719),
#  DecisionTreeClassifier(max_features='auto', random_state=1460950263),
#  DecisionTreeClassifier(max_features='auto', random_state=1510101963),
#  DecisionTreeClassifier(max_features='auto', random_state=1007242493),
#  DecisionTreeClassifier(max_features='auto', random_state=1990778990),
#  DecisionTreeClassifier(max_features='auto', random_state=63500712),
#  DecisionTreeClassifier(max_features='auto', random_state=573887951),
#  DecisionTreeClassifier(max_features='auto', random_state=2082942241),
#  DecisionTreeClassifier(max_features='auto', random_state=996385450),
#  DecisionTreeClassifier(max_features='auto', random_state=299223693),
#  DecisionTreeClassifier(max_features='auto', random_state=2122102602),
#  DecisionTreeClassifier(max_features='auto', random_state=47776987),
#  DecisionTreeClassifier(max_features='auto', random_state=1667106099),
#  DecisionTreeClassifier(max_features='auto', random_state=2099337434),
#  DecisionTreeClassifier(max_features='auto', random_state=1521999899),
#  DecisionTreeClassifier(max_features='auto', random_state=1863158985),
#  DecisionTreeClassifier(max_features='auto', random_state=498931203),
#  DecisionTreeClassifier(max_features='auto', random_state=364878168),
#  DecisionTreeClassifier(max_features='auto', random_state=465518149),
#  DecisionTreeClassifier(max_features='auto', random_state=1586181513),
#  DecisionTreeClassifier(max_features='auto', random_state=860623217),
#  DecisionTreeClassifier(max_features='auto', random_state=27113475),
#  DecisionTreeClassifier(max_features='auto', random_state=632644603),
#  DecisionTreeClassifier(max_features='auto', random_state=590986565),
#  DecisionTreeClassifier(max_features='auto', random_state=968305082),
#  DecisionTreeClassifier(max_features='auto', random_state=1669187346),
#  DecisionTreeClassifier(max_features='auto', random_state=1470055729),
#  DecisionTreeClassifier(max_features='auto', random_state=1843347824),
#  DecisionTreeClassifier(max_features='auto', random_state=1158746536),
#  DecisionTreeClassifier(max_features='auto', random_state=925120181),
#  DecisionTreeClassifier(max_features='auto', random_state=1810367700),
#  DecisionTreeClassifier(max_features='auto', random_state=2053438802),
#  DecisionTreeClassifier(max_features='auto', random_state=701954468),
#  DecisionTreeClassifier(max_features='auto', random_state=1328121850),
#  DecisionTreeClassifier(max_features='auto', random_state=771129317),
#  DecisionTreeClassifier(max_features='auto', random_state=980218287),
#  DecisionTreeClassifier(max_features='auto', random_state=1781403229),
#  DecisionTreeClassifier(max_features='auto', random_state=1000784628),
#  DecisionTreeClassifier(max_features='auto', random_state=946906714),
#  DecisionTreeClassifier(max_features='auto', random_state=1652066555),
#  DecisionTreeClassifier(max_features='auto', random_state=1418810873),
#  DecisionTreeClassifier(max_features='auto', random_state=970697510),
#  DecisionTreeClassifier(max_features='auto', random_state=572719895),
#  DecisionTreeClassifier(max_features='auto', random_state=69732994),
#  DecisionTreeClassifier(max_features='auto', random_state=1262595088),
#  DecisionTreeClassifier(max_features='auto', random_state=1647481126),
#  DecisionTreeClassifier(max_features='auto', random_state=1300758566),
#  DecisionTreeClassifier(max_features='auto', random_state=1054301090),
#  DecisionTreeClassifier(max_features='auto', random_state=1214005265),
#  DecisionTreeClassifier(max_features='auto', random_state=1661571447),
#  DecisionTreeClassifier(max_features='auto', random_state=21366960),
#  DecisionTreeClassifier(max_features='auto', random_state=695092832),
#  DecisionTreeClassifier(max_features='auto', random_state=2060179231),
#  DecisionTreeClassifier(max_features='auto', random_state=1392622920),
#  DecisionTreeClassifier(max_features='auto', random_state=819934401),
#  DecisionTreeClassifier(max_features='auto', random_state=671467107),
#  DecisionTreeClassifier(max_features='auto', random_state=1163666539),
#  DecisionTreeClassifier(max_features='auto', random_state=1680956577),
#  DecisionTreeClassifier(max_features='auto', random_state=1800837487),
#  DecisionTreeClassifier(max_features='auto', random_state=558169933),
#  DecisionTreeClassifier(max_features='auto', random_state=374489262),
#  DecisionTreeClassifier(max_features='auto', random_state=666941511),
#  DecisionTreeClassifier(max_features='auto', random_state=877714896),
#  DecisionTreeClassifier(max_features='auto', random_state=1304342740),
#  DecisionTreeClassifier(max_features='auto', random_state=545670709),
#  DecisionTreeClassifier(max_features='auto', random_state=988196898),
#  DecisionTreeClassifier(max_features='auto', random_state=1191220280),
#  DecisionTreeClassifier(max_features='auto', random_state=1065027799),
#  DecisionTreeClassifier(max_features='auto', random_state=904183477),
#  DecisionTreeClassifier(max_features='auto', random_state=268461023),
#  DecisionTreeClassifier(max_features='auto', random_state=903578584),
#  DecisionTreeClassifier(max_features='auto', random_state=424441940),
#  DecisionTreeClassifier(max_features='auto', random_state=1087724732),
#  DecisionTreeClassifier(max_features='auto', random_state=1494947638),
#  DecisionTreeClassifier(max_features='auto', random_state=492204116),
#  DecisionTreeClassifier(max_features='auto', random_state=191401836),
#  DecisionTreeClassifier(max_features='auto', random_state=56809221),
#  DecisionTreeClassifier(max_features='auto', random_state=1733118301),
#  DecisionTreeClassifier(max_features='auto', random_state=1837061286),
#  DecisionTreeClassifier(max_features='auto', random_state=917795268),
#  DecisionTreeClassifier(max_features='auto', random_state=200915455),
#  DecisionTreeClassifier(max_features='auto', random_state=566287793),
#  DecisionTreeClassifier(max_features='auto', random_state=52320347),
#  DecisionTreeClassifier(max_features='auto', random_state=2144029704),
#  DecisionTreeClassifier(max_features='auto', random_state=148383298),
#  DecisionTreeClassifier(max_features='auto', random_state=941335704),
#  DecisionTreeClassifier(max_features='auto', random_state=388198483),
#  DecisionTreeClassifier(max_features='auto', random_state=520944756),
#  DecisionTreeClassifier(max_features='auto', random_state=800585501),
#  DecisionTreeClassifier(max_features='auto', random_state=608938446),
#  DecisionTreeClassifier(max_features='auto', random_state=253027151),
#  DecisionTreeClassifier(max_features='auto', random_state=325377760),
#  DecisionTreeClassifier(max_features='auto', random_state=2140693988),
#  DecisionTreeClassifier(max_features='auto', random_state=1764109032),
#  DecisionTreeClassifier(max_features='auto', random_state=1281253758),
#  DecisionTreeClassifier(max_features='auto', random_state=2135822196),
#  DecisionTreeClassifier(max_features='auto', random_state=1752194390),
#  DecisionTreeClassifier(max_features='auto', random_state=1011292392),
#  DecisionTreeClassifier(max_features='auto', random_state=2056512349),
#  DecisionTreeClassifier(max_features='auto', random_state=1657310613),
#  DecisionTreeClassifier(max_features='auto', random_state=655570793),
#  DecisionTreeClassifier(max_features='auto', random_state=1315289950),
#  DecisionTreeClassifier(max_features='auto', random_state=720512876),
#  DecisionTreeClassifier(max_features='auto', random_state=436355846),
#  DecisionTreeClassifier(max_features='auto', random_state=1877090318),
#  DecisionTreeClassifier(max_features='auto', random_state=1281304550),
#  DecisionTreeClassifier(max_features='auto', random_state=1225346841),
#  DecisionTreeClassifier(max_features='auto', random_state=909045440),
# ...
#  DecisionTreeClassifier(max_features='auto', random_state=1757723644),
#  DecisionTreeClassifier(max_features='auto', random_state=1164281708),
#  DecisionTreeClassifier(max_features='auto', random_state=1131028434),
#  DecisionTreeClassifier(max_features='auto', random_state=621658289),
#  DecisionTreeClassifier(max_features='auto', random_state=658182917),
#  DecisionTreeClassifier(max_features='auto', random_state=1995927336),
#  DecisionTreeClassifier(max_features='auto', random_state=755564856),
#  DecisionTreeClassifier(max_features='auto', random_state=1958375900),
#  DecisionTreeClassifier(max_features='auto', random_state=1812829980),
#  DecisionTreeClassifier(max_features='auto', random_state=37961543),
#  DecisionTreeClassifier(max_features='auto', random_state=712230139),
#  DecisionTreeClassifier(max_features='auto', random_state=1313366016),
#  DecisionTreeClassifier(max_features='auto', random_state=1921547475),
#  DecisionTreeClassifier(max_features='auto', random_state=203312698),
#  DecisionTreeClassifier(max_features='auto', random_state=482557522),
#  DecisionTreeClassifier(max_features='auto', random_state=4598794),
#  DecisionTreeClassifier(max_features='auto', random_state=1711570476),
#  DecisionTreeClassifier(max_features='auto', random_state=762257827),
#  DecisionTreeClassifier(max_features='auto', random_state=1443962592),
#  DecisionTreeClassifier(max_features='auto', random_state=1946512716),
#  DecisionTreeClassifier(max_features='auto', random_state=1581598504),
#  DecisionTreeClassifier(max_features='auto', random_state=799566467),
#  DecisionTreeClassifier(max_features='auto', random_state=997137549),
#  DecisionTreeClassifier(max_features='auto', random_state=366466395),
#  DecisionTreeClassifier(max_features='auto', random_state=2098704273),
#  DecisionTreeClassifier(max_features='auto', random_state=1548202902),
#  DecisionTreeClassifier(max_features='auto', random_state=1386582492),
#  DecisionTreeClassifier(max_features='auto', random_state=812793822),
#  DecisionTreeClassifier(max_features='auto', random_state=1315122741),
#  DecisionTreeClassifier(max_features='auto', random_state=137161303),
#  DecisionTreeClassifier(max_features='auto', random_state=1427015694),
#  DecisionTreeClassifier(max_features='auto', random_state=818907342),
#  DecisionTreeClassifier(max_features='auto', random_state=43169961),
#  DecisionTreeClassifier(max_features='auto', random_state=1424644759),
#  DecisionTreeClassifier(max_features='auto', random_state=509133275),
#  DecisionTreeClassifier(max_features='auto', random_state=1316078958),
#  DecisionTreeClassifier(max_features='auto', random_state=91411611),
#  DecisionTreeClassifier(max_features='auto', random_state=1944712616),
#  DecisionTreeClassifier(max_features='auto', random_state=904266040),
#  DecisionTreeClassifier(max_features='auto', random_state=392302102),
#  DecisionTreeClassifier(max_features='auto', random_state=1706078024),
#  DecisionTreeClassifier(max_features='auto', random_state=1528119828),
#  DecisionTreeClassifier(max_features='auto', random_state=1761317221),
#  DecisionTreeClassifier(max_features='auto', random_state=1650763222),
#  DecisionTreeClassifier(max_features='auto', random_state=444315161),
#  DecisionTreeClassifier(max_features='auto', random_state=821599536),
#  DecisionTreeClassifier(max_features='auto', random_state=1414933328),
#  DecisionTreeClassifier(max_features='auto', random_state=283851826),
#  DecisionTreeClassifier(max_features='auto', random_state=1580549404),
#  DecisionTreeClassifier(max_features='auto', random_state=1625010097),
#  DecisionTreeClassifier(max_features='auto', random_state=1272420571),
#  DecisionTreeClassifier(max_features='auto', random_state=1534064087),
#  DecisionTreeClassifier(max_features='auto', random_state=1979363856),
#  DecisionTreeClassifier(max_features='auto', random_state=2060387465),
#  DecisionTreeClassifier(max_features='auto', random_state=564147551),
#  DecisionTreeClassifier(max_features='auto', random_state=1550845309),
#  DecisionTreeClassifier(max_features='auto', random_state=301564377),
#  DecisionTreeClassifier(max_features='auto', random_state=366619265),
#  DecisionTreeClassifier(max_features='auto', random_state=2035701151),
#  DecisionTreeClassifier(max_features='auto', random_state=1989600312),
#  DecisionTreeClassifier(max_features='auto', random_state=1197325322),
#  DecisionTreeClassifier(max_features='auto', random_state=1366224820),
#  DecisionTreeClassifier(max_features='auto', random_state=1093414395),
#  DecisionTreeClassifier(max_features='auto', random_state=904711902),
#  DecisionTreeClassifier(max_features='auto', random_state=2133352612),
#  DecisionTreeClassifier(max_features='auto', random_state=90153288),
#  DecisionTreeClassifier(max_features='auto', random_state=1722793025),
#  DecisionTreeClassifier(max_features='auto', random_state=2014465767),
#  DecisionTreeClassifier(max_features='auto', random_state=126721048),
#  DecisionTreeClassifier(max_features='auto', random_state=1065938342),
#  DecisionTreeClassifier(max_features='auto', random_state=1495458312),
#  DecisionTreeClassifier(max_features='auto', random_state=428954089),
#  DecisionTreeClassifier(max_features='auto', random_state=4586297),
#  DecisionTreeClassifier(max_features='auto', random_state=1825928205),
#  DecisionTreeClassifier(max_features='auto', random_state=205552330),
#  DecisionTreeClassifier(max_features='auto', random_state=663760960),
#  DecisionTreeClassifier(max_features='auto', random_state=1871155312),
#  DecisionTreeClassifier(max_features='auto', random_state=803791006),
#  DecisionTreeClassifier(max_features='auto', random_state=746970740),
#  DecisionTreeClassifier(max_features='auto', random_state=1096939873),
#  DecisionTreeClassifier(max_features='auto', random_state=540694516),
#  DecisionTreeClassifier(max_features='auto', random_state=1958511690),
#  DecisionTreeClassifier(max_features='auto', random_state=889279193),
#  DecisionTreeClassifier(max_features='auto', random_state=1648065436),
#  DecisionTreeClassifier(max_features='auto', random_state=207670301),
#  DecisionTreeClassifier(max_features='auto', random_state=1225676924),
#  DecisionTreeClassifier(max_features='auto', random_state=1404570506),
#  DecisionTreeClassifier(max_features='auto', random_state=930168971),
#  DecisionTreeClassifier(max_features='auto', random_state=1022240040),
#  DecisionTreeClassifier(max_features='auto', random_state=1099861576),
#  DecisionTreeClassifier(max_features='auto', random_state=605492281),
#  DecisionTreeClassifier(max_features='auto', random_state=1587777774),
#  DecisionTreeClassifier(max_features='auto', random_state=595145588),
#  DecisionTreeClassifier(max_features='auto', random_state=316403913),
#  DecisionTreeClassifier(max_features='auto', random_state=1436809030),
#  DecisionTreeClassifier(max_features='auto', random_state=821711762),
#  DecisionTreeClassifier(max_features='auto', random_state=1294809162),
#  DecisionTreeClassifier(max_features='auto', random_state=696968763),
#  DecisionTreeClassifier(max_features='auto', random_state=236169344),
#  DecisionTreeClassifier(max_features='auto', random_state=1439935555),
#  DecisionTreeClassifier(max_features='auto', random_state=226627694),
#  DecisionTreeClassifier(max_features='auto', random_state=992341894),
#  DecisionTreeClassifier(max_features='auto', random_state=1473806388),
#  DecisionTreeClassifier(max_features='auto', random_state=1865933078),
#  DecisionTreeClassifier(max_features='auto', random_state=1280312379),
#  DecisionTreeClassifier(max_features='auto', random_state=1214678999),
#  DecisionTreeClassifier(max_features='auto', random_state=835759601),
#  DecisionTreeClassifier(max_features='auto', random_state=347443812),
#  DecisionTreeClassifier(max_features='auto', random_state=83809955),
#  DecisionTreeClassifier(max_features='auto', random_state=569799189),
#  DecisionTreeClassifier(max_features='auto', random_state=407242750),
#  DecisionTreeClassifier(max_features='auto', random_state=1965844186),
#  DecisionTreeClassifier(max_features='auto', random_state=761353756),
#  DecisionTreeClassifier(max_features='auto', random_state=674150179),
#  DecisionTreeClassifier(max_features='auto', random_state=1773451386),
#  DecisionTreeClassifier(max_features='auto', random_state=35946192),
#  DecisionTreeClassifier(max_features='auto', random_state=183335409),
#  DecisionTreeClassifier(max_features='auto', random_state=1114102874),
#  DecisionTreeClassifier(max_features='auto', random_state=1612721900),
#  DecisionTreeClassifier(max_features='auto', random_state=688232036),
#  DecisionTreeClassifier(max_features='auto', random_state=273007815),
#  DecisionTreeClassifier(max_features='auto', random_state=164661274),
#  DecisionTreeClassifier(max_features='auto', random_state=870549245),
#  DecisionTreeClassifier(max_features='auto', random_state=210654647),
#  DecisionTreeClassifier(max_features='auto', random_state=1446816709),
#  DecisionTreeClassifier(max_features='auto', random_state=677533923),
#  DecisionTreeClassifier(max_features='auto', random_state=663137370),
#  DecisionTreeClassifier(max_features='auto', random_state=1718763990),
#  DecisionTreeClassifier(max_features='auto', random_state=359775008),
#  DecisionTreeClassifier(max_features='auto', random_state=767796172),
#  DecisionTreeClassifier(max_features='auto', random_state=1992940879),
#  DecisionTreeClassifier(max_features='auto', random_state=67750590),
#  DecisionTreeClassifier(max_features='auto', random_state=1618198190),
#  DecisionTreeClassifier(max_features='auto', random_state=1775455533),
#  DecisionTreeClassifier(max_features='auto', random_state=1869733727),
#  DecisionTreeClassifier(max_features='auto', random_state=150352397),
#  DecisionTreeClassifier(max_features='auto', random_state=1069832041),
#  DecisionTreeClassifier(max_features='auto', random_state=198195339),
#  DecisionTreeClassifier(max_features='auto', random_state=1008494427),
#  DecisionTreeClassifier(max_features='auto', random_state=1836750824),
#  DecisionTreeClassifier(max_features='auto', random_state=390010510),
#  DecisionTreeClassifier(max_features='auto', random_state=1906211794),
#  DecisionTreeClassifier(max_features='auto', random_state=1703937932),
#  DecisionTreeClassifier(max_features='auto', random_state=1178123918),
#  DecisionTreeClassifier(max_features='auto', random_state=266057362),
#  DecisionTreeClassifier(max_features='auto', random_state=70508170),
#  DecisionTreeClassifier(max_features='auto', random_state=1298299192),
#  DecisionTreeClassifier(max_features='auto', random_state=41948131),
#  DecisionTreeClassifier(max_features='auto', random_state=447937302),
#  DecisionTreeClassifier(max_features='auto', random_state=419628155),
#  DecisionTreeClassifier(max_features='auto', random_state=1246832339),
#  DecisionTreeClassifier(max_features='auto', random_state=1748684512),
#  DecisionTreeClassifier(max_features='auto', random_state=702621617),
#  DecisionTreeClassifier(max_features='auto', random_state=2103404614),
#  DecisionTreeClassifier(max_features='auto', random_state=799992625),
#  DecisionTreeClassifier(max_features='auto', random_state=1260929226),
#  DecisionTreeClassifier(max_features='auto', random_state=1958617624),
#  DecisionTreeClassifier(max_features='auto', random_state=172393323),
#  DecisionTreeClassifier(max_features='auto', random_state=1890754686),
#  DecisionTreeClassifier(max_features='auto', random_state=1162323335),
#  DecisionTreeClassifier(max_features='auto', random_state=268165819),
#  DecisionTreeClassifier(max_features='auto', random_state=128844624),
#  DecisionTreeClassifier(max_features='auto', random_state=2117847289),
#  DecisionTreeClassifier(max_features='auto', random_state=1130968163),
#  DecisionTreeClassifier(max_features='auto', random_state=300073757),
#  DecisionTreeClassifier(max_features='auto', random_state=127008418),
#  DecisionTreeClassifier(max_features='auto', random_state=655848034),
#  DecisionTreeClassifier(max_features='auto', random_state=7312760),
#  DecisionTreeClassifier(max_features='auto', random_state=819103052),
#  DecisionTreeClassifier(max_features='auto', random_state=1381069389),
#  DecisionTreeClassifier(max_features='auto', random_state=1754165992),
#  DecisionTreeClassifier(max_features='auto', random_state=4750120),
#  DecisionTreeClassifier(max_features='auto', random_state=475859808),
#  DecisionTreeClassifier(max_features='auto', random_state=1966490720),
#  DecisionTreeClassifier(max_features='auto', random_state=474322676),
#  DecisionTreeClassifier(max_features='auto', random_state=1447535000),
#  DecisionTreeClassifier(max_features='auto', random_state=146132399),
#  DecisionTreeClassifier(max_features='auto', random_state=1410349106),
#  DecisionTreeClassifier(max_features='auto', random_state=235664908),
#  DecisionTreeClassifier(max_features='auto', random_state=7443264),
#  DecisionTreeClassifier(max_features='auto', random_state=795564133),
#  DecisionTreeClassifier(max_features='auto', random_state=602600535),
#  DecisionTreeClassifier(max_features='auto', random_state=681026964),
#  DecisionTreeClassifier(max_features='auto', random_state=44028401),
#  DecisionTreeClassifier(max_features='auto', random_state=802963580),
#  DecisionTreeClassifier(max_features='auto', random_state=931437167),
#  DecisionTreeClassifier(max_features='auto', random_state=1889484448),
#  DecisionTreeClassifier(max_features='auto', random_state=229426104),
#  DecisionTreeClassifier(max_features='auto', random_state=1148148514),
#  DecisionTreeClassifier(max_features='auto', random_state=320263947),
#  DecisionTreeClassifier(max_features='auto', random_state=1584926207),
#  DecisionTreeClassifier(max_features='auto', random_state=1264430817),
#  DecisionTreeClassifier(max_features='auto', random_state=91707883),
#  DecisionTreeClassifier(max_features='auto', random_state=144922565),
#  DecisionTreeClassifier(max_features='auto', random_state=1433275512),
#  DecisionTreeClassifier(max_features='auto', random_state=1025880207),
#  DecisionTreeClassifier(max_features='auto', random_state=887108210),
#  DecisionTreeClassifier(max_features='auto', random_state=1740194980),
#  DecisionTreeClassifier(max_features='auto', random_state=1845609562),
#  DecisionTreeClassifier(max_features='auto', random_state=602784936),
#  DecisionTreeClassifier(max_features='auto', random_state=1822278306),
#  DecisionTreeClassifier(max_features='auto', random_state=1350971126),
#  DecisionTreeClassifier(max_features='auto', random_state=503975061),
#  DecisionTreeClassifier(max_features='auto', random_state=683366435),
#  DecisionTreeClassifier(max_features='auto', random_state=1576939396),
#  DecisionTreeClassifier(max_features='auto', random_state=304847946),
#  DecisionTreeClassifier(max_features='auto', random_state=34867824),
#  DecisionTreeClassifier(max_features='auto', random_state=1296901125),
#  DecisionTreeClassifier(max_features='auto', random_state=531813126),
#  DecisionTreeClassifier(max_features='auto', random_state=44230452),
#  DecisionTreeClassifier(max_features='auto', random_state=1918084081),
#  DecisionTreeClassifier(max_features='auto', random_state=1928168312),
#  DecisionTreeClassifier(max_features='auto', random_state=2130008120),
#  DecisionTreeClassifier(max_features='auto', random_state=976905214),
#  DecisionTreeClassifier(max_features='auto', random_state=2131426027),
#  DecisionTreeClassifier(max_features='auto', random_state=1049285432),
#  DecisionTreeClassifier(max_features='auto', random_state=622905135),
#  DecisionTreeClassifier(max_features='auto', random_state=698042982),
#  DecisionTreeClassifier(max_features='auto', random_state=1274330238),
#  DecisionTreeClassifier(max_features='auto', random_state=17463965),
#  DecisionTreeClassifier(max_features='auto', random_state=594297005),
#  DecisionTreeClassifier(max_features='auto', random_state=1306790505),
#  DecisionTreeClassifier(max_features='auto', random_state=125028641),
#  DecisionTreeClassifier(max_features='auto', random_state=1933097419),
#  DecisionTreeClassifier(max_features='auto', random_state=716323862),
#  DecisionTreeClassifier(max_features='auto', random_state=164211730),
#  DecisionTreeClassifier(max_features='auto', random_state=1456115496)]

# %%
def save_df(df, path):
    """
    Dataframe that will be saved as picke object at specified path.
        args:
            df (dataframe): dataframe that will be converted and saved as pickle.
            path (string): location where the pickle will be placed.
        returns:
            -
    """

    pickle.dump(df, open(path, "wb"))

# %%
## Loading pickle.
def load_df(path):
    """
    Loading pickle.
        args:
            path (string): specific location of pickle that will be loaded.
        returns:
            pickle_load (*various*): loaded pickle object; most likely a dataframe.
    """

    pickle_load = pickle.load(open(path, "rb"))

    return pickle_load

# %%
## Save fe data frame as pickle. (feature engeniering)
def save_fe(df, path):
    """
    Save fe data frame as pickle.
        args:
            df (dataframe): fe resulting dataframe.
            path (string): location where the pickle object will be stored.
        returns:
            -
    """

    save_df(df, path)
